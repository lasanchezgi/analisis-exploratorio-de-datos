# %% [markdown]
# # Análisis univariado

# %% [markdown]
# ## Explorando una variable categórica

# %%
import empiricaldist
import janitor
import matplotlib.pyplot as plt
import numpy as np
import palmerpenguins
import pandas as pd
import scipy.stats
import seaborn as sns
import sklearn.metrics
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

# %%
df = palmerpenguins.load_penguins()
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %% [markdown]
# ### Conteos y proporciones

# %% [markdown]
# #### Preludio: ¿Qué estadísticos describen el conjunto de datos?

# %% [markdown]
# ###### Todas las variables

# %%
df.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex         year
# count    342.000000   333   344.000000
# unique          NaN     2          NaN
# top             NaN  male          NaN
# freq            NaN   168          NaN
# mean    4201.754386   NaN  2008.029070
# std      801.954536   NaN     0.818356
# min     2700.000000   NaN  2007.000000
# 25%     3550.000000   NaN  2007.000000
# 50%     4050.000000   NaN  2008.000000
# 75%     4750.000000   NaN  2009.000000
# max     6300.000000   NaN  2009.000000

# %% [markdown]
# ###### Solo variables númericas

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# ###### Solo variables categoricas

# %%
df.describe(include='O')
# Out:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       152     168   168

# %%
df.astype({
    'species' : 'category',
    'island' : 'category',
    'sex' : 'category'
}).describe(include='category')
# Out:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       152     168   168

# %% [markdown]
# #### ¿Cómo visualizar los conteos?

# %% [markdown]
# ##### Pandas

# %%
df['species'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ##### Seaborn

# %%
sns.catplot(data=df, x='species', kind='count', palette=penguin_color)
plt.show()

# %%
df.value_counts('species', sort=True).reset_index(name='count').pipe(lambda df1 : (sns.barplot (data=df1, x='species', y='count', palette=penguin_color)))
plt.show()

# %%
df.value_counts('island', sort=True).reset_index(name='count').pipe(lambda df1 : (sns.barplot (data=df1, x='island', y='count')))
plt.show()

# %%
df.value_counts('sex', sort=True).reset_index(name='count').pipe(lambda df1 : (sns.barplot (data=df1, x='sex', y='count')))
plt.show()

# %% [markdown]
# #### ¿Cómo visualizar las proporciones?

# %%
df.add_column('x', '').pipe(lambda df1: (sns.displot(data=df1, x='x', hue='species', multiple='fill', palette=penguin_color)))
plt.show()

# %%
df.add_column('x', '').pipe(lambda df1: (sns.displot(data=df1, x='x', hue='island', multiple='fill')))
plt.show()

# %%
df.add_column('x', '').pipe(lambda df1: (sns.displot(data=df1, x='x', hue='sex', multiple='fill')))
plt.show()

# %% [markdown]
# ## Estadística descriptiva aplicada

# %% [markdown]
# ### Medidas de tendecnia central

# %% [markdown]
# #### Media o promedio

# %%
df['bill_depth_mm'].mean()
# Out:
# 17.151169590643274

# %%
np.mean(df['bill_depth_mm'])
# Out:
# 17.151169590643274

# %%
df.mean()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# bill_length_mm         43.921930
# bill_depth_mm          17.151170
# flipper_length_mm     200.915205
# body_mass_g          4201.754386
# year                 2008.029070
# dtype: float64

# %% [markdown]
# #### Mediana

# %%
df.median()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# bill_length_mm         44.45
# bill_depth_mm          17.30
# flipper_length_mm     197.00
# body_mass_g          4050.00
# year                 2008.00
# dtype: float64

# %% [markdown]
# #### Moda

# %%
df.mode()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe            41.1           17.0              190.0
#
#    body_mass_g   sex  year
# 0       3800.0  male  2009

# %%
df.describe(include=object)
# Out:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       152     168   168

# %% [markdown]
# ### Medidas de dispersión

# %% [markdown]
# #### ¿Cuál es el valor máximo de las variables?

# %%
df.max(numeric_only=True)
# Out:
# bill_length_mm         59.6
# bill_depth_mm          21.5
# flipper_length_mm     231.0
# body_mass_g          6300.0
# year                 2009.0
# dtype: float64

# %% [markdown]
# #### ¿Cuál es el valor mínimo de las variables?

# %%
df.min(numeric_only=True)
# Out:
# bill_length_mm         32.1
# bill_depth_mm          13.1
# flipper_length_mm     172.0
# body_mass_g          2700.0
# year                 2007.0
# dtype: float64

# %% [markdown]
# #### ¿Cuál es el rango de las variables?

# %%
df.max(numeric_only=True) - df.min(numeric_only=True)
# Out:
# bill_length_mm         27.5
# bill_depth_mm           8.4
# flipper_length_mm      59.0
# body_mass_g          3600.0
# year                    2.0
# dtype: float64

# %% [markdown]
# #### ¿Cuál es la desviación estándar de las variables?

# %%
df.std(numeric_only=True)
# Out:
# bill_length_mm         5.459584
# bill_depth_mm          1.974793
# flipper_length_mm     14.061714
# body_mass_g          801.954536
# year                   0.818356
# dtype: float64

# %%
df.mean(numeric_only=True) - df.std(numeric_only=True)
# Out:
# bill_length_mm         38.462346
# bill_depth_mm          15.176376
# flipper_length_mm     186.853491
# body_mass_g          3399.799850
# year                 2007.210714
# dtype: float64

# %%
df.mean(numeric_only=True) + df.std(numeric_only=True)
# Out:
# bill_length_mm         49.381514
# bill_depth_mm          19.125963
# flipper_length_mm     214.976918
# body_mass_g          5003.708922
# year                 2008.847426
# dtype: float64

# %% [markdown]
# #### ¿Cuál es el rango intercuartílico?

# %%
df.quantile(0.25)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\3656653379.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0.25)
# bill_length_mm         39.225
# bill_depth_mm          15.600
# flipper_length_mm     190.000
# body_mass_g          3550.000
# year                 2007.000
# Name: 0.25, dtype: float64

# %%
df.quantile(0.75)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\3799946287.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0.75)
# bill_length_mm         48.5
# bill_depth_mm          18.7
# flipper_length_mm     213.0
# body_mass_g          4750.0
# year                 2009.0
# Name: 0.75, dtype: float64

# %%
df.quantile(0.75) - df.quantile(0.25)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\4199850847.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0.75) - df.quantile(0.25)
# bill_length_mm          9.275
# bill_depth_mm           3.100
# flipper_length_mm      23.000
# body_mass_g          1200.000
# year                    2.000
# dtype: float64

# %%
df.quantile(q=[0.25,0.50,0.75])
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\3893509287.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(q=[0.25,0.50,0.75])
#       bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g    year
# 0.25          39.225           15.6              190.0       3550.0  2007.0
# 0.50          44.450           17.3              197.0       4050.0  2008.0
# 0.75          48.500           18.7              213.0       4750.0  2009.0

# %%
df.quantile(q=[0.25,0.50,0.75]).transpose().rename_axis('variable').reset_index().assign(iqr= lambda df1: df1[0.75] - df1[0.25])
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\3951764436.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(q=[0.25,0.50,0.75]).transpose().rename_axis('variable').reset_index().assign(iqr= lambda df1: df1[0.75] - df1[0.25])
#             variable      0.25      0.5    0.75       iqr
# 0     bill_length_mm    39.225    44.45    48.5     9.275
# 1      bill_depth_mm    15.600    17.30    18.7     3.100
# 2  flipper_length_mm   190.000   197.00   213.0    23.000
# 3        body_mass_g  3550.000  4050.00  4750.0  1200.000
# 4               year  2007.000  2008.00  2009.0     2.000

# %% [markdown]
# #### ¿Cómo puedo visualizar la distribución de una variable?

# %% [markdown]
# ##### Histograma

# %%
sns.histplot(data=df, x='flipper_length_mm')
plt.axvline(x=df['flipper_length_mm'].mean(), color='red', linestyle='dashed', linewidth=2)
plt.axvline(x=df['flipper_length_mm'].median(), color='blue', linestyle='dashed', linewidth=2)
plt.show()

# %%
sns.histplot(data=df, x='flipper_length_mm', binwidth=5)
plt.axvline(x=df['flipper_length_mm'].mean(), color='red', linestyle='dashed', linewidth=2)
plt.axvline(x=df['flipper_length_mm'].median(), color='blue', linestyle='dashed', linewidth=2)
plt.show()

# %%
sns.histplot(data=df, x='flipper_length_mm', binwidth=3)
plt.axvline(x=df['flipper_length_mm'].mean(), color='red', linestyle='dashed', linewidth=2)
plt.axvline(x=df['flipper_length_mm'].median(), color='blue', linestyle='dashed', linewidth=2)
plt.show()

# %%
sns.histplot(data=df, x='flipper_length_mm', binwidth=1)
plt.axvline(x=df['flipper_length_mm'].mean(), color='red', linestyle='dashed', linewidth=2)
plt.axvline(x=df['flipper_length_mm'].median(), color='blue', linestyle='dashed', linewidth=2)
plt.show()

# %% [markdown]
# ###### Limitaciones

# %%
def freedman_diaconis_binwidth(x: pd.Series) -> float:
    """"Find optimal binwidth usiong Freedman-Diaconis rule."""

    IQR = x.quantile(0.75) - x.quantile(0.25)
    N = x.size

    return 2 * IQR / N ** (1/3)

# %%
freedman_diaconis_binwidth(df['flipper_length_mm'])
# Out:
# 6.565054727883573

# %%
sns.histplot(data=df, x='flipper_length_mm', binwidth=freedman_diaconis_binwidth(df['flipper_length_mm']))
plt.axvline(x=df['flipper_length_mm'].mean(), color='red', linestyle='dashed', linewidth=2)
plt.axvline(x=df['flipper_length_mm'].median(), color='blue', linestyle='dashed', linewidth=2)
plt.show()

# %% [markdown]
# ##### Boxplot

# %%
sns.boxplot(data=df, x='flipper_length_mm')
plt.show()

# %% [markdown]
# ### Distribuciones

# %% [markdown]
# #### Funciones de densidad de probabilidad

# %% [markdown]
# ##### Seaborn

# %%
sns.histplot(data=df, x='flipper_length_mm', binwidth=1, stat='probability')
plt.show()

# %% [markdown]
# ##### empiricaldist

# %%
pmf_flipper_length_mm = empiricaldist.Pmf.from_seq(df['flipper_length_mm'], normalize=True)
pmf_flipper_length_mm
# Out:
# 172.0    0.002924
# 174.0    0.002924
# 176.0    0.002924
# 178.0    0.011696
# 179.0    0.002924
# 180.0    0.014620
# 181.0    0.020468
# 182.0    0.008772
# 183.0    0.005848
# 184.0    0.020468
# 185.0    0.026316
# 186.0    0.020468
# 187.0    0.046784
# 188.0    0.017544
# 189.0    0.020468
# 190.0    0.064327
# 191.0    0.038012
# 192.0    0.020468
# 193.0    0.043860
# 194.0    0.014620
# 195.0    0.049708
# 196.0    0.029240
# 197.0    0.029240
# 198.0    0.023392
# 199.0    0.017544
# 200.0    0.011696
# 201.0    0.017544
# 202.0    0.011696
# 203.0    0.014620
# 205.0    0.008772
# 206.0    0.002924
# 207.0    0.005848
# 208.0    0.023392
# 209.0    0.014620
# 210.0    0.040936
# 211.0    0.005848
# 212.0    0.020468
# 213.0    0.017544
# 214.0    0.017544
# 215.0    0.035088
# 216.0    0.023392
# 217.0    0.017544
# 218.0    0.014620
# 219.0    0.014620
# 220.0    0.023392
# 221.0    0.014620
# 222.0    0.017544
# 223.0    0.005848
# 224.0    0.008772
# 225.0    0.011696
# 226.0    0.002924
# 228.0    0.011696
# 229.0    0.005848
# 230.0    0.020468
# 231.0    0.002924
# Name: , dtype: float64

# %%
type(pmf_flipper_length_mm)
# Out:
# empiricaldist.empiricaldist.Pmf

# %%
pmf_flipper_length_mm.bar()

# %%
pmf_flipper_length_mm(190)
# Out:
# 0.06432748538011696

# %%
sns.kdeplot(data=df, x='flipper_length_mm')
plt.show()

# %%
sns.kdeplot(data=df, x='flipper_length_mm', bw_method=0.1)
plt.show()

# %%
stats = df['body_mass_g'].describe()
stats
# Out:
# count     342.000000
# mean     4201.754386
# std       801.954536
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4750.000000
# max      6300.000000
# Name: body_mass_g, dtype: float64

# %%
xs = np.linspace(stats['min'], stats['max'])
ys = scipy.stats.norm(stats['mean'], stats['std']).cdf(xs)

plt.plot(xs, ys, color='black', linestyle='dashed')
empiricaldist.Cdf.from_seq(df['body_mass_g'], normalize=True).plot()

plt.show()

# %%
xs = np.linspace(stats['min'], stats['max'])
ys = scipy.stats.norm(stats['mean'], stats['std']).pdf(xs)

plt.plot(xs, ys, color='black', linestyle='dashed')
sns.kdeplot(data=df, x='body_mass_g')

plt.show()

# %% [markdown]
# #### Funciones empirícas de probabiblidad acumulada (ECDFs)

# %% [markdown]
# ##### Seaborn

# %%
sns.ecdfplot(data=df, x='flipper_length_mm')
plt.show()

# %% [markdown]
# ##### Empiricaldist

# %%
cdf_flipper_length_mm = empiricaldist.Cdf.from_seq(df['flipper_length_mm'], normalize=True)
cdf_flipper_length_mm
# Out:
# 172.0    0.002924
# 174.0    0.005848
# 176.0    0.008772
# 178.0    0.020468
# 179.0    0.023392
# 180.0    0.038012
# 181.0    0.058480
# 182.0    0.067251
# 183.0    0.073099
# 184.0    0.093567
# 185.0    0.119883
# 186.0    0.140351
# 187.0    0.187135
# 188.0    0.204678
# 189.0    0.225146
# 190.0    0.289474
# 191.0    0.327485
# 192.0    0.347953
# 193.0    0.391813
# 194.0    0.406433
# 195.0    0.456140
# 196.0    0.485380
# 197.0    0.514620
# 198.0    0.538012
# 199.0    0.555556
# 200.0    0.567251
# 201.0    0.584795
# 202.0    0.596491
# 203.0    0.611111
# 205.0    0.619883
# 206.0    0.622807
# 207.0    0.628655
# 208.0    0.652047
# 209.0    0.666667
# 210.0    0.707602
# 211.0    0.713450
# 212.0    0.733918
# 213.0    0.751462
# 214.0    0.769006
# 215.0    0.804094
# 216.0    0.827485
# 217.0    0.845029
# 218.0    0.859649
# 219.0    0.874269
# 220.0    0.897661
# 221.0    0.912281
# 222.0    0.929825
# 223.0    0.935673
# 224.0    0.944444
# 225.0    0.956140
# 226.0    0.959064
# 228.0    0.970760
# 229.0    0.976608
# 230.0    0.997076
# 231.0    1.000000
# Name: , dtype: float64

# %%
cdf_flipper_length_mm.plot()
# Out:
# <AxesSubplot: >

# %%
q = 200
p = cdf_flipper_length_mm.forward(q)
print(q, p)
# Out:
# 200 0.5672514619883041

# %%
cdf_flipper_length_mm.plot()

q = 200
p = cdf_flipper_length_mm.forward(q)

plt.vlines(x=q, ymin=0, ymax=p, color='black', linestyles='dashed')
plt.hlines(y=p, xmin=pmf_flipper_length_mm.qs[0], xmax=q, color='black', linestyles='dashed')
plt.plot(q,p, 'ro')

plt.show()

# %% [markdown]
# #### Comparando distribuciones

# %%
sns.ecdfplot(data=df, x='flipper_length_mm', hue='species', palette=penguin_color)
plt.show()

# %%
sns.ecdfplot(data=df, x='flipper_length_mm', hue='island')
plt.show()

# %%
sns.ecdfplot(data=df, x='flipper_length_mm', hue='sex')
plt.show()

# %% [markdown]
# ## Bonus

# %% [markdown]
# ### Ley de los números grandes

# %%
dice = empiricaldist.Pmf.from_seq([1,2,3,4,5,6])
dice.bar()

# %%
dice = empiricaldist.Pmf.from_seq(np.arange(1, 7))

for sample_size in [1e2, 1e3, 1e4]:
    sample_size = int(sample_size)
    values = dice.sample(sample_size)
    sample_pmf = empiricaldist.Pmf.from_seq(values)

    plt.figure(figsize=(5,5))
    sample_pmf.bar()
    plt.axhline(y=1/6, color='red', linestyle='dashed')
    plt.ylim([0, 0.50])
    plt.title(f'Sample size: {sample_size}')
    plt.show()

# %% [markdown]
# ### Teorema del límite central

# %%
df['sex'].value_counts(normalize=True)
# Out:
# male      0.504505
# female    0.495495
# Name: sex, dtype: float64

# %%
df['sex'].value_counts(normalize=True)*100
# Out:
# male      50.45045
# female    49.54955
# Name: sex, dtype: float64

# %%
df['sex'].value_counts(normalize=True).plot(kind='bar')
plt.show()

# %%
sex_numeric = df['sex'].replace(['male', 'female'], [1,0])

# %%
number_samples = 1000
sample_size = 35

samples_df = pd.DataFrame()

np.random.seed(42)
for i in range(1, number_samples + 1):
    sex_numeric_sample = sex_numeric.sample(sample_size, replace = True).to_numpy()
    sample_name = f'sample_{i}'
    samples_df[sample_name] = sex_numeric_sample

male_population_mean = samples_df.mean().mean()
print(f'Estimated percentage of male penguins in population is: {male_population_mean*100:.4f}%')
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# ...
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9012\1221915089.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# Estimated percentage of male penguins in population is: 50.5906%

# %%
sample_means_binomial = pd.DataFrame(samples_df.mean(), columns=['sample_name'])
sns.kdeplot(data=sample_means_binomial)
plt.axvline(x=sex_numeric.mean(), color='red', linestyle='dashed')
plt.show()

# %%
sample_size_experiment = pd.DataFrame(
    [[i, samples_df.iloc[:, 0:i].mean().mean().mean()] for i in range(1, number_samples + 1)],
    columns=['sample_size', 'estimated_mean']
)

sns.scatterplot(data=sample_size_experiment, x='sample_size', y='estimated_mean')
plt.axhline(y=sex_numeric.mean(), color='red', linestyle='dashed')
plt.ylim([sex_numeric.mean() - 0.20, sex_numeric.mean() + 0.2])
plt.show()
